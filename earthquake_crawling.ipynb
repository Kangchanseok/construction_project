# %%
import bs4
import os
import time
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys

# %%
my_ser = Service('chromedriver.exe')
my_dri = webdriver.Chrome(service=my_ser)

# %%
my_dri.get('https://www.weather.go.kr/w/eqk-vol/archive/stat/trend.do')

# %%
eqk = my_dri.find_element(By.CSS_SELECTOR,'#eqk-trend > tbody')
eqk_lst = test.text.split()
eqk_year = []
eqk_cnt = []
for i in range(0,len(eqk_lst),4):
    eqk_year.append(int(eqk_lst[i]))
for i in range(3,len(eqk_lst),4):
    eqk_cnt.append(int(eqk_lst[i]))

# %%
df = pd.DataFrame(data = list(zip(eqk_year,eqk_cnt)), columns = ['연도', '총 횟수'])
# df.set_index(keys = '연도')
df
# Out:
#       연도  총 횟수
# 0   1978     6
# 1   1979    22
# 2   1980    16
# 3   1981    15
# 4   1982    13
# 5   1983    20
# 6   1984    19
# 7   1985    26
# 8   1986    15
# 9   1987    11
# 10  1988     6
# 11  1989    16
# 12  1990    15
# 13  1991    19
# 14  1992    15
# 15  1993    22
# 16  1994    24
# 17  1995    29
# 18  1996    39
# 19  1997    21
# 20  1998    32
# 21  1999    37
# 22  2000    29
# 23  2001    41
# 24  2002    49
# 25  2003    38
# 26  2004    42
# 27  2005    37
# 28  2006    50
# 29  2007    42
# 30  2008    46
# 31  2009    60
# 32  2010    42
# 33  2011    52
# 34  2012    56
# 35  2013    93
# 36  2014    49
# 37  2015    44
# 38  2016   252
# 39  2017   223
# 40  2018   115
# 41  2019    88
# 42  2020    68
# 43  2021    70
# 44  2022    77

# %%
# %matplotlib inline
np.set_printoptions(precision=3)
pd.set_option("display.precision",3)
# %precision %.3f

# %%
df.plot.bar(color = 'pink',x = '연도', y = '총 횟수',fontsize = 8)
plt.rcParams['font.family'] = 'Malgun Gothic' # 한글패치
# .xaxis.set_major_locator(MaxNLocator(5))
